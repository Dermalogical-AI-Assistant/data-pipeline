# %%
import pandas as pd
df = pd.read_csv(r'csv/products.csv')

# %%
df = df.drop(columns=['title_embedding', 'description_embedding', 'description_embedding', 'id', 'ingredient_benefits_embedding', 'page_url', 'total_ingredients', 'product_ingredients_description'])
df.loc[df['preprocessed_ingredients'].notna(), 'full_ingredients_list'] = df.loc[df['preprocessed_ingredients'].notna(), 'preprocessed_ingredients'] 
df = df.drop(columns=['preprocessed_ingredients'])
df
# Out:
#                             _id  \
# 0      68134808b42bba0085f0c8bc
# 1      6813455fb42bba0085f0b52c
# 2      681344bbb42bba0085f0b070
# 3      68134622b42bba0085f0bac6
# 4      681347d8b42bba0085f0c764
# ...                         ...
# 13094  683043b7fdb3859600e38257
# 13095  683043b7fdb3859600e38258
# 13096  683043b7fdb3859600e38259
# 13097  683043b7fdb3859600e3825a
# 13098  683043b7fdb3859600e3825b
#
#                                                      img  \
# 0      https://www.lookfantastic.com/images?url=https...
# 1      https://www.lookfantastic.com/images?url=https...
# 2      https://www.lookfantastic.com/images?url=https...
# 3      https://www.lookfantastic.com/images?url=https...
# 4      https://www.lookfantastic.com/images?url=https...
# ...                                                  ...
# 13094  https://www.lookfantastic.com/images?url=https...
# 13095  https://www.lookfantastic.com/images?url=https...
# ...

# %%
df.to_csv('csv/initial_product_all_backup.csv', index=False)

# %%
df = pd.read_csv(r'csv/initial_product_all_backup.csv')
df
# Out:
#                             _id  \
# 0      68134808b42bba0085f0c8bc
# 1      6813455fb42bba0085f0b52c
# 2      681344bbb42bba0085f0b070
# 3      68134622b42bba0085f0bac6
# 4      681347d8b42bba0085f0c764
# ...                         ...
# 13094  683043b7fdb3859600e38257
# 13095  683043b7fdb3859600e38258
# 13096  683043b7fdb3859600e38259
# 13097  683043b7fdb3859600e3825a
# 13098  683043b7fdb3859600e3825b
#
#                                                      img  \
# 0      https://www.lookfantastic.com/images?url=https...
# 1      https://www.lookfantastic.com/images?url=https...
# 2      https://www.lookfantastic.com/images?url=https...
# 3      https://www.lookfantastic.com/images?url=https...
# 4      https://www.lookfantastic.com/images?url=https...
# ...                                                  ...
# 13094  https://www.lookfantastic.com/images?url=https...
# 13095  https://www.lookfantastic.com/images?url=https...
# ...
